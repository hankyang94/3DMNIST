# %%
import gzip
import h5py
import pickle
import os
import numpy as np
from farthest_point_sampling import img_to_point_cloud

try:
    from tqdm import trange
except ImportError:
    trange = range

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import pyplot as plt

# %matplotlib inline
plt.rcParams['image.interpolation'] = None
plt.rcParams['image.cmap'] = 'gray'

# %%
with gzip.open('data/mnist.pkl.gz','rb') as ff :     
    u = pickle._Unpickler( ff )
    u.encoding = 'latin1'
    train_set, valid_set, test_set = u.load()

# %%
print(train_set[0].shape)
print(valid_set[0].shape)
print(test_set[0].shape)
# Out:
# (50000, 784)
# (10000, 784)
# (10000, 784)

# %%
# test sample images and hyperparameters
k=30
idx = 34568

img = train_set[0][idx].reshape(28,28)
label = train_set[1][idx]
print('Digit label: ',label)

cloud_3D = img_to_point_cloud(img,k)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(cloud_3D[:,0], cloud_3D[:,1], cloud_3D[:,2], color='r', marker='o')
ax.view_init(90, 0)
plt.show()
# Out:
# Digit label:  7

# %%
# function to save dataset to h5
def save_dataset(X, y, k, output):
    with h5py.File(output, "w") as hf:
        count = 0;
        for i in trange(len(X)):
            img = X[i].reshape(28, 28)
            
            cloud = img_to_point_cloud(img,k)
            
            if cloud is None:
                print('Skipping the ', i, '-th image.')
            else:
                grp = hf.create_group(str(count))
                grp.create_dataset("img", data=img, compression="gzip")
                grp.create_dataset("points", data=cloud, compression="gzip")
                grp.attrs["label"] = y[count]
                count += 1

# %%
OUTPUT_TRAIN = "data/train.h5"
N_TRAIN = train_set[0].shape[0]
OUTPUT_TEST = "data/test.h5"
N_TEST = test_set[0].shape[0]
OUTPUT_VALID = "data/valid.h5"
N_VALID = valid_set[0].shape[0]

# %%
k=30
if os.path.exists(OUTPUT_TRAIN):
    print (OUTPUT_TRAIN, "Already exists")
else:
    save_dataset(train_set[0][:N_TRAIN], train_set[1][:N_TRAIN], k, OUTPUT_TRAIN)

if os.path.exists(OUTPUT_TEST):
    print (OUTPUT_TEST, "Already exists")
else:
    save_dataset(test_set[0][:N_TEST], test_set[1][:N_TEST], k, OUTPUT_TEST)

if os.path.exists(OUTPUT_VALID):
    print (OUTPUT_VALID, "Already exists")
else:
    save_dataset(valid_set[0][:N_VALID], valid_set[1][:N_VALID], k, OUTPUT_VALID)
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]
#
#   0%|          | 1/50000 [00:00<2:03:32,  6.74it/s]
#
#   0%|          | 2/50000 [00:00<2:06:38,  6.58it/s]
#
#   0%|          | 4/50000 [00:00<1:49:12,  7.63it/s]
#
#   0%|          | 5/50000 [00:00<1:44:16,  7.99it/s]
#
#   0%|          | 6/50000 [00:00<1:49:03,  7.64it/s]
#
#   0%|          | 8/50000 [00:00<1:48:20,  7.69it/s]
#
#   0%|          | 10/50000 [00:01<1:33:38,  8.90it/s]
#
#   0%|          | 11/50000 [00:01<1:40:04,  8.33it/s]
#
#   0%|          | 13/50000 [00:01<1:41:18,  8.22it/s]
#
#   0%|          | 14/50000 [00:01<1:46:23,  7.83it/s]
#
#   0%|          | 16/50000 [00:01<1:33:45,  8.89it/s]
#
#   0%|          | 17/50000 [00:01<1:37:31,  8.54it/s]
#
#   0%|          | 18/50000 [00:02<1:43:00,  8.09it/s]
#
#   0%|          | 20/50000 [00:02<1:27:53,  9.48it/s]
#
#   0%|          | 22/50000 [00:02<1:44:11,  7.99it/s]
#
#   0%|          | 166/50000 [00:20<2:04:25,  6.68it/s]
#
#   0%|          | 168/50000 [00:20<1:54:46,  7.24it/s]
#
#   0%|          | 169/50000 [00:20<1:56:18,  7.14it/s]
#
#   0%|          | 170/50000 [00:21<2:13:03,  6.24it/s]
#
#   0%|          | 171/50000 [00:21<1:58:19,  7.02it/s]
#
#   0%|          | 172/50000 [00:21<2:07:40,  6.50it/s]
#
#   0%|          | 173/50000 [00:21<1:59:18,  6.96it/s]
#
#   0%|          | 176/50000 [00:21<1:40:32,  8.26it/s]
#
#   0%|          | 178/50000 [00:21<1:33:42,  8.86it/s]
#
#   0%|          | 179/50000 [00:21<1:38:17,  8.45it/s]
#
#   0%|          | 180/50000 [00:22<1:55:17,  7.20it/s]
#
#   0%|          | 182/50000 [00:22<1:51:44,  7.43it/s]
#
#   0%|          | 183/50000 [00:22<1:52:21,  7.39it/s]
#
#   0%|          | 184/50000 [00:22<1:51:42,  7.43it/s]
#
#   0%|          | 186/50000 [00:22<1:41:35,  8.17it/s]
#
#   0%|          | 187/50000 [00:22<1:38:47,  8.40it/s]
#
#   0%|          | 188/50000 [00:23<2:01:31,  6.83it/s]
#
#   0%|          | 189/50000 [00:23<2:00:11,  6.91it/s]
#
#   0%|          | 190/50000 [00:23<2:07:13,  6.52it/s]
#
#   0%|          | 191/50000 [00:23<2:08:10,  6.48it/s]
#
#   0%|          | 193/50000 [00:23<1:57:10,  7.08it/s]
#
#   0%|          | 194/50000 [00:23<1:53:38,  7.31it/s]
#   0%|          | 195/50000 [00:24<2:00:29,  6.89it/s]
#
#   0%|          | 196/50000 [00:24<1:51:31,  7.44it/s]
#
#   0%|          | 197/50000 [00:24<1:49:57,  7.55it/s]
#
#   0%|          | 198/50000 [00:24<1:47:03,  7.75it/s]
#
#   0%|          | 199/50000 [00:24<1:48:41,  7.64it/s]
#
#   0%|          | 200/50000 [00:24<1:51:19,  7.46it/s]
#
#   0%|          | 202/50000 [00:24<1:37:38,  8.50it/s]
#
#   0%|          | 203/50000 [00:25<1:40:31,  8.26it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-bc3b0adda06d> in <module>()
#       3     print (OUTPUT_TRAIN, "Already exists")
#       4 else:
# ----> 5     save_dataset(train_set[0][:N_TRAIN], train_set[1][:N_TRAIN], k, OUTPUT_TRAIN)
#       6
#       7 if os.path.exists(OUTPUT_TEST):
#
# <ipython-input-19-631b2e7ace23> in save_dataset(X, y, k, output)
#       7             img = X[i].reshape(28, 28)
#       8
# ----> 9             cloud = img_to_point_cloud(img,k)
#      10
#      11             if cloud is None:
#
# /home/hank/Documents/myPyVision/3DMNIST/farthest_point_sampling.py in img_to_point_cloud(img, k)
#      14     else:
#      15         # use farthest sampling to get downsampled coordinates
# ---> 16         cloud_2D = np.array(incremental_farthest_search(non_zero_coord,k))
#      17         # center the point cloud
#      18         mean = np.mean(cloud_2D,axis=0);
#
# /home/hank/Documents/myPyVision/3DMNIST/farthest_point_sampling.py in incremental_farthest_search(points, k)
#      37         for i, p in enumerate(remaining_points):
#      38             for j, s in enumerate(solution_set):
# ---> 39                 distances[i] = min(distances[i], distance(p, s))
#      40         solution_set.append(remaining_points.pop(distances.index(max(distances))))
#      41     return solution_set
#
# /home/hank/Documents/myPyVision/3DMNIST/farthest_point_sampling.py in distance(A, B)
#      43
#      44 def distance(A,B):
# ---> 45     return sum((A-B)**2)
#      46
#      47
#
# KeyboardInterrupt:
